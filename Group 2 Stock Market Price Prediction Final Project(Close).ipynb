# %%
#doing all the imports and downloads done previously
import pandas as pd
import numpy as np 
from numpy.random import RandomState
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential 
from keras.layers import Dense,LSTM,Dropout

# %%
data = pd.read_csv('C:/Users/Shahroze/TSLA.csv')
data.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
train, test = train_test_split(data, test_size=0.3)
print("\nTrain:\n")
print(train.head())
print(train.shape)

print("\nTest:\n")
print(test.head())
print(test.shape)
# Out:
# Train:
#
#             Date        Open        High         Low       Close   Adj Close  \
# 273   2011-07-28   27.600000   28.549999   27.540001   28.170000   28.170000
# 382   2012-01-03   28.940001   29.500000   27.650000   28.080000   28.080000
# 697   2013-04-08   41.970001   42.549999   41.509998   41.830002   41.830002
# 1136  2015-01-02  222.869995  223.250000  213.259995  219.309998  219.309998
# 1113  2014-11-28  245.350006  246.690002  242.520004  244.520004  244.520004
#
#        Volume
# 273    938700
# 382    928100
# 697   1679000
# 1136  4764400
# 1113  2119700
# (1691, 7)
#
# Test:
#
#             Date        Open        High         Low       Close   Adj Close  \
# 186   2011-03-24   22.139999   22.379999   21.980000   22.330000   22.330000
# 1816  2017-09-14  364.329987  377.959991  362.630005  377.640015  377.640015
# 2024  2018-07-13  315.579987  319.579987  309.250000  318.869995  318.869995
# 284   2011-08-12   25.600000   27.139999   25.360001   26.309999   26.309999
# 775   2013-07-29  129.320007  135.369995  128.250000  134.619995  134.619995
#
#        Volume
# 186    462200
# 1816  7202500
# 2024  5869800
# 284   1009100
# 775   9678900
# (725, 7)

# %%
train.to_csv('train.csv')
test.to_csv('test.csv')

# %%
df = pd.read_csv('C:/Users/Shahroze/train.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2011-07-28   27.600000   28.549999   27.540001   28.170000   28.170000
# 1  2012-01-03   28.940001   29.500000   27.650000   28.080000   28.080000
# 2  2013-04-08   41.970001   42.549999   41.509998   41.830002   41.830002
# 3  2015-01-02  222.869995  223.250000  213.259995  219.309998  219.309998
# 4  2014-11-28  245.350006  246.690002  242.520004  244.520004  244.520004
#
#     Volume
# 0   938700
# 1   928100
# 2  1679000
# 3  4764400
# 4  2119700

# %%
dg = pd.read_csv('C:/Users/Shahroze/test.csv')
dg.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2011-03-24   22.139999   22.379999   21.980000   22.330000   22.330000
# 1  2017-09-14  364.329987  377.959991  362.630005  377.640015  377.640015
# 2  2018-07-13  315.579987  319.579987  309.250000  318.869995  318.869995
# 3  2011-08-12   25.600000   27.139999   25.360001   26.309999   26.309999
# 4  2013-07-29  129.320007  135.369995  128.250000  134.619995  134.619995
#
#     Volume
# 0   462200
# 1  7202500
# 2  5869800
# 3  1009100
# 4  9678900

# %%
#Changing the Close variable from an object to a float value
df["Close"] = pd.to_numeric(data.Close,errors='coerce')
df = df.dropna()
traindf = df.iloc[:,4:5].values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 0 to 1690
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1691 non-null   object
#  1   Open       1691 non-null   float64
#  2   High       1691 non-null   float64
#  3   Low        1691 non-null   float64
#  4   Close      1691 non-null   float64
#  5   Adj Close  1691 non-null   float64
#  6   Volume     1691 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.6+ KB

# %%
#rescaling data to make sure  it's easier to handle 
sc = MinMaxScaler(feature_range=(0,1))
traindf = sc.fit_transform(traindf)
traindf.shape
# Out:
# (1691, 1)

# %%
#Preparing data for training
#the lenght of the data is 1691 while the steps taken 60
X_train = []
y_train = []

for m in range (60,1691): 
    X_train.append(traindf[m-60:m,0])
    y_train.append(traindf[m,0])

X_train, y_train = np.array(X_train),np.array(y_train)

# %%
#addding the batch size to allow the model to be updated after the varying smaple processes
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_train.shape
# Out:
# (1631, 60, 1)

# %%
#building a model containing 4 layers of LSTM network with 4 layers of network and the dense layer
model = Sequential()

model.add(LSTM(units=100, return_sequences = True, input_shape =(X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=100,return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units =1))
model.compile(optimizer='adam',loss="mean_squared_error")

# %%
#Training our model Close
hist = model.fit(X_train, y_train, epochs = 20, batch_size =32, verbose=2)
# Out:
# Epoch 1/20
# 51/51 - 11s - loss: 0.0286 - 11s/epoch - 206ms/step
# Epoch 2/20
# 51/51 - 4s - loss: 0.0049 - 4s/epoch - 85ms/step
# Epoch 3/20
# 51/51 - 4s - loss: 0.0044 - 4s/epoch - 85ms/step
# Epoch 4/20
# 51/51 - 4s - loss: 0.0046 - 4s/epoch - 81ms/step
# Epoch 5/20
# 51/51 - 4s - loss: 0.0039 - 4s/epoch - 82ms/step
# Epoch 6/20
# 51/51 - 4s - loss: 0.0040 - 4s/epoch - 86ms/step
# Epoch 7/20
# 51/51 - 4s - loss: 0.0034 - 4s/epoch - 85ms/step
# Epoch 8/20
# 51/51 - 4s - loss: 0.0034 - 4s/epoch - 84ms/step
# Epoch 9/20
# 51/51 - 4s - loss: 0.0039 - 4s/epoch - 84ms/step
# Epoch 10/20
# 51/51 - 4s - loss: 0.0033 - 4s/epoch - 87ms/step
# Epoch 11/20
# 51/51 - 4s - loss: 0.0033 - 4s/epoch - 85ms/step
# Epoch 12/20
# 51/51 - 4s - loss: 0.0038 - 4s/epoch - 85ms/step
# Epoch 13/20
# 51/51 - 4s - loss: 0.0030 - 4s/epoch - 86ms/step
# Epoch 14/20
# 51/51 - 4s - loss: 0.0031 - 4s/epoch - 87ms/step
# Epoch 15/20
# 51/51 - 4s - loss: 0.0029 - 4s/epoch - 86ms/step
# Epoch 16/20
# 51/51 - 4s - loss: 0.0028 - 4s/epoch - 86ms/step
# Epoch 17/20
# 51/51 - 4s - loss: 0.0026 - 4s/epoch - 88ms/step
# Epoch 18/20
# 51/51 - 4s - loss: 0.0024 - 4s/epoch - 87ms/step
# Epoch 19/20
# 51/51 - 4s - loss: 0.0026 - 4s/epoch - 86ms/step
# Epoch 20/20
# 51/51 - 4s - loss: 0.0027 - 4s/epoch - 86ms/step

# %%
plt.plot(hist.history['loss'])
plt.title('Training Model Loss Close')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
#Running the model under Test
#importing dataset
testdf = pd.read_csv('C:/Users/Shahroze/test.csv')
testdf["Close"]=pd.to_numeric(testdf.Close,errors='coerce')
testdf =testdf.dropna()
testdf = testdf.iloc[:,4:5]
y_test = testdf.iloc[60:,0:].values
#the input array for the model
#selecting the Closing 
inputClosing = testdf.iloc[:,0:].values
inputClosing_scaled = sc.transform(inputClosing)
inputClosing_scaled.shape
X_test = []
lenght = len(testdf)
timestep = 60 
for m in range(timestep, lenght): 
        X_test.append(inputClosing_scaled[m-timestep:m,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
X_test.shape
# Out:
# (665, 60, 1)

# %%
#predicting the model output using the function X_test data
y_pred = model.predict(X_test)
y_pred
# Out:
# 21/21 [==============================] - 2s 27ms/step
# array([[0.7175074 ],
#        [0.7105021 ],
#        [0.71875274],
#        [0.74417233],
#        [0.77845806],
#        [0.78874254],
#        [0.76916325],
#        [0.7324741 ],
#        [0.6917928 ],
#        [0.6418599 ],
#        [0.5967883 ],
#        [0.57603645],
#        [0.57968956],
#        [0.60302   ],
#        [0.61971897],
#        [0.6126067 ],
#        [0.57809454],
#        [0.5206722 ],
#        [0.46068382],
#        [0.41908875],
#        [0.39280277],
#        [0.38565597],
#        [0.4148515 ],
#        [0.46987426],
#        [0.52007484],
#        [0.5434328 ],
#        [0.55074376],
#        [0.5551178 ],
#        [0.5691057 ],
#        [0.596174  ],
#        [0.6440885 ],
#        [0.7181228 ],
#        [0.7971548 ],
#        [0.8572303 ],
#        [0.8898465 ],
#        [0.89883786],
#        [0.8896252 ],
#        [0.8487656 ],
#        [0.7758933 ],
#        [0.69368184],
#        [0.61960894],
#        [0.5520786 ],
#        [0.48730433],
#        [0.43612087],
#        [0.39439383],
#        [0.3561152 ],
#        [0.31786516],
#        [0.28788242],
#        [0.26471537],
#        [0.25429517],
#        [0.2780149 ],
#        [0.32378516],
#        [0.38780397],
#        [0.44616657],
#        [0.5074907 ],
#        [0.57849574],
#        [0.6582171 ],
#        [0.7299428 ],
#        [0.76242286],
#        [0.77439916],
#        [0.755291  ],
#        [0.7168607 ],
#        [0.6762898 ],
#        [0.6276335 ],
#        [0.5937042 ],
#        [0.58352053],
#        [0.6032504 ],
#        [0.6554247 ],
#        [0.70015395],
#        [0.72142893],
#        [0.7207076 ],
#        [0.7096864 ],
#        [0.6797108 ],
#        [0.6374884 ],
#        [0.6079553 ],
#        [0.59630114],
#        [0.6066635 ],
#        [0.63420874],
#        [0.66956043],
#        [0.7077926 ],
#        [0.7221249 ],
#        [0.71633804],
#        [0.69004667],
#        [0.65714717],
#        [0.63719845],
#        [0.6449446 ],
#        [0.6544628 ],
#        [0.6443286 ],
#        [0.6073849 ],
#        [0.56066614],
#        [0.52194124],
#        [0.5048289 ],
#        [0.49682605],
#        [0.50793934],
#        [0.51979667],
#        [0.5286733 ],
#        [0.5383145 ],
#        [0.5637144 ],
#        [0.6026436 ],
#        [0.629424  ],
#        [0.644816  ],
#        [0.6371601 ],
#        [0.6024645 ],
#        [0.56852394],
#        [0.5329635 ],
#        [0.50656486],
#        [0.49937603],
#        [0.5279828 ],
#        [0.5654492 ],
#        [0.60075045],
#        [0.6136947 ],
#        [0.6142218 ],
#        [0.611517  ],
#        [0.61714774],
#        [0.61519027],
#        [0.60798   ],
#        [0.60656226],
#        [0.6263158 ],
#        [0.65056646],
#        [0.6725891 ],
#        [0.68181366],
#        [0.6898218 ],
#        [0.7042814 ],
#        [0.7285529 ],
#        [0.735869  ],
#        [0.7413437 ],
#        [0.7277204 ],
#        [0.7042853 ],
#        [0.672335  ],
#        [0.64159065],
#        [0.62352645],
#        [0.6179866 ],
#        [0.6148286 ],
#        [0.6179173 ],
#        [0.6259418 ],
#        [0.64299625],
#        [0.6713391 ],
#        [0.7188226 ],
#        [0.78240913],
#        [0.85387635],
#        [0.88865834],
#        [0.8691209 ],
#        [0.82573825],
#        [0.79032534],
#        [0.7494642 ],
#        [0.7128873 ],
#        [0.69925374],
#        [0.6959251 ],
#        [0.7011914 ],
#        [0.7146924 ],
#        [0.7121561 ],
#        [0.7061522 ],
#        [0.708867  ],
#        [0.7159855 ],
#        [0.73143595],
#        [0.7541954 ],
#        [0.7787575 ],
#        [0.80012274],
#        [0.82208616],
#        [0.83673537],
#        [0.8409657 ],
#        [0.8439377 ],
#        [0.82372946],
#        [0.79218525],
#        [0.75845623],
#        [0.72547424],
#        [0.7033942 ],
#        [0.6897868 ],
#        [0.6982791 ],
#        [0.7017053 ],
#        [0.6982955 ],
#        [0.67557794],
#        [0.65703315],
#        [0.6667368 ],
#        [0.6943082 ],
#        [0.72768724],
#        [0.7696738 ],
#        [0.8123902 ],
#        [0.850158  ],
#        [0.88142586],
#        [0.898811  ],
#        [0.89159656],
#        [0.8566955 ],
#        [0.8136664 ],
#        [0.7744564 ],
#        [0.74711066],
#        [0.7137032 ],
#        [0.66367096],
#        [0.61153984],
#        [0.5756886 ],
#        [0.5652856 ],
#        [0.5871798 ],
#        [0.61315924],
#        [0.6191226 ],
#        [0.59598696],
#        [0.5595619 ],
#        [0.5353193 ],
#        [0.54703474],
#        [0.5715017 ],
#        [0.583709  ],
#        [0.58824617],
#        [0.58866227],
#        [0.5759644 ],
#        [0.5655709 ],
#        [0.56686527],
#        [0.5835879 ],
#        [0.5954121 ],
#        [0.6121469 ],
#        [0.64546   ],
#        [0.6690996 ],
#        [0.69376785],
#        [0.7160707 ],
#        [0.7398126 ],
#        [0.7748718 ],
#        [0.8578987 ],
#        [0.9552876 ],
#        [1.0233233 ],
#        [1.0469106 ],
#        [1.0430422 ],
#        [1.0172029 ],
#        [0.9617656 ],
#        [0.8830437 ],
#        [0.79771686],
#        [0.71978253],
#        [0.66059554],
#        [0.6081828 ],
#        [0.5529702 ],
#        [0.5011816 ],
#        [0.4729863 ],
#        [0.48431668],
#        [0.535053  ],
#        [0.5880401 ],
#        [0.6473886 ],
#        [0.70270485],
#        [0.7517504 ],
#        [0.7998799 ],
#        [0.9198069 ],
#        [1.0750067 ],
#        [1.1943213 ],
#        [1.2535474 ],
#        [1.2215225 ],
#        [1.1178159 ],
#        [0.9720144 ],
#        [0.80752295],
#        [0.63956517],
#        [0.48085207],
#        [0.34989056],
#        [0.27017966],
#        [0.23849085],
#        [0.23731445],
#        [0.25204617],
#        [0.27463457],
#        [0.31161124],
#        [0.37778786],
#        [0.4699508 ],
#        [0.5855772 ],
#        [0.67915887],
#        [0.74603784],
#        [0.80301523],
#        [0.83743405],
#        [0.83027256],
#        [0.8004771 ],
#        [0.7716492 ],
#        [0.75939935],
#        [0.77323323],
#        [0.8046425 ],
#        [0.8407212 ],
#        [0.86508495],
#        [0.85175365],
#        [0.8024146 ],
#        [0.7427972 ],
#        [0.6724134 ],
#        [0.5922562 ],
#        [0.52020895],
#        [0.4731365 ],
#        [0.46307573],
#        [0.4707429 ],
#        [0.49599713],
#        [0.5175528 ],
#        [0.5464082 ],
#        [0.59372777],
#        [0.6521823 ],
#        [0.7274066 ],
#        [0.7780849 ],
#        [0.81197035],
#        [0.8094345 ],
#        [0.790037  ],
#        [0.7473275 ],
#        [0.6821101 ],
#        [0.5995369 ],
#        [0.5304441 ],
#        [0.50202626],
#        [0.499751  ],
#        [0.51510566],
#        [0.5478986 ],
#        [0.57296056],
#        [0.5932409 ],
#        [0.62638587],
#        [0.6788666 ],
#        [0.717833  ],
#        [0.7206373 ],
#        [0.69919294],
#        [0.679268  ],
#        [0.66910106],
#        [0.6734502 ],
#        [0.66980594],
#        [0.6735034 ],
#        [0.6862367 ],
#        [0.7087763 ],
#        [0.7242668 ],
#        [0.74485904],
#        [0.76461387],
#        [0.7847382 ],
#        [0.825483  ],
#        [0.84802556],
#        [0.8502434 ],
#        [0.849465  ],
#        [0.84469426],
#        [0.8154329 ],
#        [0.75662714],
#        [0.69312453],
#        [0.6423449 ],
#        [0.5954874 ],
#        [0.5441484 ],
#        [0.49811745],
#        [0.48336968],
#        [0.50262415],
#        [0.54916143],
#        [0.6105731 ],
#        [0.65298486],
#        [0.6572583 ],
#        [0.6388195 ],
#        [0.6000372 ],
#        [0.5444227 ],
#        [0.4987387 ],
#        [0.47574356],
#        [0.4639656 ],
#        [0.45147616],
#        [0.4297166 ],
#        [0.41893494],
#        [0.44038168],
#        [0.49961162],
#        [0.57714313],
#        [0.6554207 ],
#        [0.7010545 ],
#        [0.721998  ],
#        [0.74070376],
#        [0.75994587],
#        [0.7562352 ],
#        [0.74586165],
#        [0.7447996 ],
#        [0.7461341 ],
#        [0.7481239 ],
#        [0.7611422 ],
#        [0.75901157],
#        [0.7275177 ],
#        [0.6834573 ],
#        [0.63884103],
#        [0.603986  ],
#        [0.56901425],
#        [0.5450933 ],
#        [0.53773004],
#        [0.5320658 ],
#        [0.5310887 ],
#        [0.5383754 ],
#        [0.5556474 ],
#        [0.5639391 ],
#        [0.57826924],
#        [0.60896444],
#        [0.6338045 ],
#        [0.6443783 ],
#        [0.6468878 ],
#        [0.6457823 ],
#        [0.6463684 ],
#        [0.6350007 ],
#        [0.60359776],
#        [0.5517825 ],
#        [0.50674593],
#        [0.49067822],
#        [0.505164  ],
#        [0.5589889 ],
#        [0.6504057 ],
#        [0.75749457],
#        [0.8493113 ],
#        [0.8855107 ],
#        [0.8808888 ],
#        [0.86596715],
#        [0.8274616 ],
#        [0.7786007 ],
#        [0.7285699 ],
#        [0.6693014 ],
#        [0.62612575],
#        [0.60894585],
#        [0.6143644 ],
#        [0.62881595],
#        [0.64817345],
#        [0.68047315],
#        [0.7348184 ],
#        [0.80207276],
#        [0.86308104],
#        [0.9283585 ],
#        [0.96766067],
#        [0.97632843],
#        [0.9704275 ],
#        [0.9309706 ],
#        [0.88087904],
#        [0.84345216],
#        [0.819681  ],
#        [0.8066276 ],
#        [0.8027336 ],
#        [0.7823219 ],
#        [0.7348163 ],
#        [0.675424  ],
#        [0.6277626 ],
#        [0.59973925],
#        [0.57643527],
#        [0.553555  ],
#        [0.5380155 ],
#        [0.5199156 ],
#        [0.50776935],
#        [0.51306427],
#        [0.531626  ],
#        [0.56308246],
#        [0.6046704 ],
#        [0.6311397 ],
#        [0.6278303 ],
#        [0.59279966],
#        [0.5326706 ],
#        [0.4715371 ],
#        [0.41370606],
#        [0.3722892 ],
#        [0.34354338],
#        [0.3265469 ],
#        [0.31415147],
#        [0.31608725],
#        [0.34441572],
#        [0.38322723],
#        [0.4425191 ],
#        [0.5242299 ],
#        [0.6301259 ],
#        [0.7149709 ],
#        [0.77908546],
#        [0.8201375 ],
#        [0.8445736 ],
#        [0.8619258 ],
#        [0.8952241 ],
#        [0.90549684],
#        [0.8939271 ],
#        [0.8473266 ],
#        [0.7827364 ],
#        [0.70193785],
#        [0.6095588 ],
#        [0.52723396],
#        [0.4669852 ],
#        [0.44140306],
#        [0.44752502],
#        [0.48264778],
#        [0.5434325 ],
#        [0.6090769 ],
#        [0.6688392 ],
#        [0.7280316 ],
#        [0.77634174],
#        [0.81005245],
#        [0.8082372 ],
#        [0.7663169 ],
#        [0.714306  ],
#        [0.6613968 ],
#        [0.629276  ],
#        [0.6308061 ],
#        [0.6542038 ],
#        [0.696847  ],
#        [0.72803825],
#        [0.7478247 ],
#        [0.7388494 ],
#        [0.72647685],
#        [0.7146446 ],
#        [0.72365373],
#        [0.7275695 ],
#        [0.7384598 ],
#        [0.7545514 ],
#        [0.75149375],
#        [0.74050885],
#        [0.73749864],
#        [0.72363865],
#        [0.6891117 ],
#        [0.63223225],
#        [0.55800575],
#        [0.4865794 ],
#        [0.43511435],
#        [0.4139553 ],
#        [0.42832968],
#        [0.48348826],
#        [0.57698876],
#        [0.66176695],
#        [0.70347697],
#        [0.7129978 ],
#        [0.68852115],
#        [0.6350761 ],
#        [0.57396656],
#        [0.5206159 ],
#        [0.48452118],
#        [0.45690393],
#        [0.45260897],
#        [0.4579492 ],
#        [0.47887993],
#        [0.4978553 ],
#        [0.52213573],
#        [0.56750524],
#        [0.6260542 ],
#        [0.6967361 ],
#        [0.766634  ],
#        [0.8261606 ],
#        [0.87357897],
#        [0.8799547 ],
#        [0.8594102 ],
#        [0.8351255 ],
#        [0.80568886],
#        [0.7849756 ],
#        [0.7756696 ],
#        [0.78646624],
#        [0.8107918 ],
#        [0.8518109 ],
#        [0.9031741 ],
#        [0.95117885],
#        [0.974731  ],
#        [0.9838323 ],
#        [0.9809933 ],
#        [0.9423539 ],
#        [0.8855311 ],
#        [0.8260149 ],
#        [0.75606596],
#        [0.6733838 ],
#        [0.5984321 ],
#        [0.55119115],
#        [0.5199719 ],
#        [0.5048723 ],
#        [0.492106  ],
#        [0.48600754],
#        [0.5032033 ],
#        [0.5256348 ],
#        [0.5576651 ],
#        [0.599546  ],
#        [0.64475495],
#        [0.7026341 ],
#        [0.7398407 ],
#        [0.75693583],
#        [0.76354444],
#        [0.74628466],
#        [0.72997564],
#        [0.73045135],
#        [0.7237268 ],
#        [0.6938686 ],
#        [0.63818467],
#        [0.56269497],
#        [0.48753113],
#        [0.4291066 ],
#        [0.39355594],
#        [0.39785168],
#        [0.42341906],
#        [0.45622894],
#        [0.5027806 ],
#        [0.5749556 ],
#        [0.669226  ],
#        [0.7625372 ],
#        [0.8363184 ],
#        [0.85964376],
#        [0.8277618 ],
#        [0.7529203 ],
#        [0.651307  ],
#        [0.54781383],
#        [0.45020646],
#        [0.37395072],
#        [0.3252192 ],
#        [0.31098223],
#        [0.31789127],
#        [0.337601  ],
#        [0.38395408],
#        [0.45834327],
#        [0.5518136 ],
#        [0.6648312 ],
#        [0.74957985],
#        [0.8549977 ],
#        [0.96158314],
#        [1.0364761 ],
#        [1.0851018 ],
#        [1.0970938 ],
#        [1.0520626 ],
#        [0.9577552 ],
#        [0.8312686 ],
#        [0.7033243 ],
#        [0.58131665],
#        [0.47996014],
#        [0.41490388],
#        [0.3772973 ],
#        [0.367927  ],
#        [0.37158832],
#        [0.40961522],
#        [0.4765669 ],
#        [0.5386567 ],
#        [0.5955178 ],
#        [0.645763  ],
#        [0.70297945],
#        [0.764104  ],
#        [0.81951594],
#        [0.8608373 ],
#        [0.86083   ],
#        [0.8340284 ],
#        [0.8103334 ],
#        [0.7904363 ],
#        [0.7876614 ],
#        [0.7874063 ],
#        [0.7665326 ],
#        [0.73175985],
#        [0.67837155],
#        [0.6224883 ],
#        [0.57907486],
#        [0.5403878 ],
#        [0.49780157],
#        [0.46460727],
#        [0.45991454],
#        [0.49401227],
#        [0.57432216],
#        [0.6541546 ],
#        [0.7240672 ],
#        [0.75535685],
#        [0.7556395 ],
#        [0.7428689 ],
#        [0.7313928 ],
#        [0.740421  ],
#        [0.76798815],
#        [0.78099227],
#        [0.7758568 ],
#        [0.76773906],
#        [0.76420367],
#        [0.765565  ],
#        [0.77023435],
#        [0.7546388 ],
#        [0.7260092 ],
#        [0.6778304 ],
#        [0.6223385 ],
#        [0.57667637],
#        [0.56605905],
#        [0.59372973],
#        [0.65716094],
#        [0.73391956],
#        [0.7797752 ],
#        [0.8094039 ],
#        [0.8054283 ],
#        [0.7888591 ],
#        [0.7678863 ],
#        [0.7296753 ],
#        [0.70063645],
#        [0.68871033],
#        [0.6803886 ],
#        [0.6583031 ],
#        [0.6552618 ],
#        [0.65396327],
#        [0.6522693 ],
#        [0.6620359 ],
#        [0.6826384 ],
#        [0.7160135 ],
#        [0.762384  ],
#        [0.7860528 ],
#        [0.80522907],
#        [0.7989107 ]], dtype=float32)

# %%
#plot predicted and actual 
predicted_price = sc.inverse_transform(y_pred)

# %%
plt.plot(y_test, color = 'green', label = 'Actual Stock Price')
plt.plot(predicted_price, color = 'red', label = 'Predicted Stock Price')
plt.title('Tesla Stock Price Predictor Closing(2010-2020)')
plt.ylabel('Stock Price')
plt.xlabel('Time')
plt.legend()

plt.grid()
plt.show()
